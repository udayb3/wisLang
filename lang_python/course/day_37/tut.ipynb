# %%
import requests as rq 
# res= rq.post(url="",json="",headers="")

# %% [markdown]
# The above post function is used for different purposes depending upon the API.

# %% [markdown]
# There are mainly 3 which we have explored:
# 1. To create the user id.
# 2. To create a graph.
# 3. To fill the box in the graph.

# %%
tok=""
user=""
tok_cr="grp1"
hdrs={
    "X-USER-TOKEN": tok
}
gr_ep=""
