# %%
from flask import Flask as fl
# __name__ is a special attribute built in python as at any given point we cna open name to know what is the currently running.
app=fl(__name__)
# There are other values 
@app.route("/")
