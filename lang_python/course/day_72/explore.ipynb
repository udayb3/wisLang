# %%
import pandas as pd

# %%
data=pd.read_csv('major.csv')

# head prints the first n rows and columns of the dataframe
display(data.head(n=1))

# columns is an attribute which contains the names of columns
display(  type(data.columns)  )

# shape returns a tuple of number of rows and columns
display(  type(data.shape)  )

# isna checks each block and returns true or false after seeing whether the value is Nan or not.
st1=data['Mid-Career 10th Percentile Salary'].isna()

# max and min return maximum and minimum values whereas idxmax and idxmin return the index of maximum and minimum values
display(  data['Mid-Career 10th Percentile Salary'].idxmax()  )

# loc takes location as the row index and the column name
display( data['Mid-Career 10th Percentile Salary'].loc[1] )

# data
# Out:
#   Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0          Accounting                 46000.0                   77100.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
#
#       Group
# 0  Business
# pandas.core.indexes.base.Index
# tuple
# 8
# 64300.0
